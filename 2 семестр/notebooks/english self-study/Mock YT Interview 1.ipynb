# %% [markdown]
# ### Source

# %% [markdown]
# Direct link: https://www.youtube.com/watch?v=rdphm7NB2MY
# Channel: EngX Space
# Title: Coding Interview Questions and Answers: Java / Mock Interview Show #1

# %% [markdown]
# ### Phrases

# %% [markdown]
# Perfect opportunity - идеальная возможность

# %% [markdown]
# Near future - в ближайшем будущем

# %% [markdown]
# Key questions - ключевые вопросы

# %% [markdown]
# Informatics graduate - выпускник факультета информатики

# %% [markdown]
# Kick off out interview - начинать наше интервью

# %% [markdown]
# According - согласно/следовательно

# %% [markdown]
# Pretty exciting - довольно захватывающе

# %% [markdown]
# Bundle - пучок/пакет

# %% [markdown]
# Inheritance - наследование

# %% [markdown]
# Polymorphism - полиморфизм

# %% [markdown]
# Reduce - уменьшать
