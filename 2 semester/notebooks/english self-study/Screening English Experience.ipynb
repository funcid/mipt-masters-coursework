# %% [markdown]
# ### 19.01.2026: Screening

# %% [markdown]
# **DISCLAIMER**: This file was created to increase my english knowledge.

# %% [markdown]
# Hello? Yeah. It's all good. Can you hear me well? Yeah. Yeah, right. Perfect. Great. So first of all, thank you for having me here today. And tell me something. Is this the first time you heard of *** or you knew about it before? Okay, perfect. So in that case, I will give you a quick overview for you to have a better idea on what are we doing at the moment, a little bit more context about the projects as well.

# %% [markdown]
# And then of course, any questions, anything else? Just feel free to ask me anytime. Okay? Perfect. Well, so quick in a quick nutshell, we started back in 2015, 10 years ago, given or taken. And since the beginning, what we want to do is to create this financial super app, a place that everyone can manage their finances in one single place in one single single application. And well, of course, that considering this, we constantly need to be adding new services, expanding the existing ones, scaling the application to new locations as well. So a lot of different demands ongoing. So far, it's working well, we were able to launch the app in 48 different countries, and we do have around 60 million users. So it is working quite nicely. But we realized that one of our major gaps was actually the absence of credit products. So back in 2020, 2021, we started working on the development and implementation of these products. And over this last couple of years, we were able to launch personal loans, credit cards, buy now pay later, we also have some business loans in a separate application, which is the business app for companies as well. And quite quite recently, we started a new project completely from scratch, that will be a fully digital mortgage product for the users as well. So we have different demands. Because what happens is as we have the app available in so many countries, each time that we want to scale these products to one of those new locations, we need to customize everything entirely. So each country is different from the other. And therefore the products, they're also different. And that's why we are hiring now because we do have most of the products available so far in 11 countries. But it means that there are 40 I mean, 30 plus more to go with. So this is one of the reasons for us to be hiring also considering the new product as well, a lot of work from scratch too. We do have over 11 teams in the credit department, we are hiring across all of them. So what we are doing is the recruitment process is exactly the same, everyone does the same technical rounds. And by the end of the technical stages, we will just book one or two team feeds for you to meet one or two different projects. And indeed that you don't mind which one should be done. But yeah, just to give you this quick context, I will tell you more things about to the specifics of the recruitment process more about the more about the technical steps and so on. But later on in the call. So tell me so far, if it's all clear, any questions, anything? I don't have a question on user stage. Yeah, okay. Perfect.

# %% [markdown]
# So in the meantime, I got the chance to read your CV, I mean, the So I do have an idea on the work that you have been doing over the past few years. But one thing is for me to read a paper. So I know that you started in 2020. And you have been progressing over time, you're currently at the MSC. So I do have an idea. But again, one thing is to read the paper. Another thing is to know more from you. So if you could tell me a little bit more in terms of recent projects, tasks, responsibilities, well, whatever you believe it is worth to mention, I would like to know a bit more than if I have questions, so we'll make them as well. Okay. Yeah, I've been writing code for five years. And now I'm a Java Kotlin software engineer. But now I'm mostly writing in Kotlin. Yeah. I'm in charge of architecture design, writing and doing tests. Our products have 90% of coverage. And sometimes I do technical interviews. And I make all the components of our project. It's a micro services. It's around five pieces. And what is the project about specifically? Can you tell me more about for me to have the context? Yeah, of course, it's a wallet. And we have some operations like transfers, cross-border transfers. Our clients, it's B2C and B2B. We have opening wallets, closing it and other operations. Okay. And what markets is the wallet working for? I mean, how many users do you have on average? Is it a big scale app or how it is? We are on the early stage. We have around 20 business clients and around 2,000 customers. And you mentioned that you were working on architecture as well. So are you involved in the system designing work like or you are going to the meetings or I mean, how much contribution you have been doing over that? Yeah, I have been doing new features and new services. We have around, not around, we have four developers. And I was at the start of this project and I was involved in all technical decisions and architecture. That's good. And you mentioned that you had 90% coverage with tests, usually the unit integration and when, what are you guys covering? We have only integration tests. We use test containers and for other services, we have mocs, but we don't use G-Unit for simple tests. Okay, I know that makes sense. Okay. And have you ever worked with test driven development before? Do you know how it works? Can you repeat this? Yes, I was asking if you ever worked with the test driven development before and you mentioned that you were working with a lot of testing. Yes, we do. We have a lot of testing, we have a lot of testing, we have a lot of testing. And we have a lot of testing. Yes, I was asking if you ever worked with the test driven development before, if you know how it works. Ah, yeah, yeah, of course. We use it sometimes, to be clear, it's depends on our storage estimates. Mm-hmm. It's like every year. Very short. Okay, okay. I was just asking because sometimes you need to do it as well. So, especially because we don't have QAs or testers. So, that's why I wanted to know. Okay, amazing. And in terms of technical stack, you mentioned Java and Kotlin, but in microservices as well. So, you work to, in terms of libraries, for example, in our case, we don't use Spring. We prefer to keep it a more low level kind of thing. So, how comfortable does that sound to you? Do you use Servlets? No, we just use a dependency injection library from Google. The architecture is also event driven, so we work with Kafka, Reddish for the cache, et cetera, and Spark for data processing. But it's quite simplified kind of way, I'd say. Oh, it's okay. I have used it in my other projects.

# %% [markdown]
# Okay, perfect. Great. And tell me something, also in any of your projects, have you ever needed to work closely with concurrency? I mean, like thread pools, concurrent collections, locks, et cetera? Yeah, of course. Can you tell me more, like what projects you worked with it and what was it for, et cetera, what you use and so on? Our project is about money and how we transfer it. It's all about the mocks and synchronization because people cannot lose their money. We must make it consistent, and that's why we use locks and other types of synchronization. Okay. But for example, if you need to make the code thread safe and just with plain Java, it's something you can do, right? Yeah, right. Of course. Okay, that's good. And as we're speaking about this though, are you familiar also on the DB side there on the transactions level with AC principles, isolation levels, optimistic, pessimistic locking, et cetera? I'm not saying every task, but yeah, I use it. For example, I need to set an isolation level for SQL queries. Okay. And let's put this there. Let's say, for example, that you have two users trying to update the same bank account balance at the same time, what you would do to guarantee that everything will work fine? Simply, I can use a locks, but it not can be so fast and optimal for this task. Maybe I would use a version fields for casting their object. I think it will be more messy. Yeah. And when it comes to lock, you would go with optimistic, pessimistic, if you have read and write at the same time. Same time. I think I'll be use optimistic, because we have a lot of queries and if we will use pessimistic, it will generate more useless, useless ends. Yes. And in terms of the isolation levels, what do you believe that would be the most appropriate case? Double writing, right? Maybe that's not the repeatable read? No. I mean, we have four, right? Two writes in one moment, right? Read committed, uncommitted, repeatable read and serializable. Those are the four, right? What task do we have? Do we have two writes in one moment or two reads in one moment? You have read and write at the same time, multiple people. I think we will use third variant. Which one, sorry? First. Ah, first or third, sorry. I think it's the connection. First is a default, but it's not a guarantee when multiple queries. Exactly. Okay. Perfect. And you mentioned that you worked with Kafka. What is the architecture that you guys currently have in the project? Is it event-driven? Yeah, right. And that's good. Okay, perfect.

# %% [markdown]
# And tell me something, you are currently in Thailand. Are you open to relocation? Yes. Okay. We have two options, Spain and Emirates. Do you have preferences? Yeah, I think United Emirates will be more less different. Okay, perfect. In terms of the relocation, we pay everything. Visa trips and then one month accommodation. We are offering gold visa. And once you are there, the salaries, it depends on the seniority that they determine for you. But for example, if we consider, let's say a mid position, we are paying around *** dirhams per year. This is a net income and there are also bonuses and equity on top, and it's an employment permanent contract. Okay. Then what we have on the project, on the process, on the recruitment process, three steps. First is a life coding. Second one, a technical conversation. And the last one, it's a system design. We usually do once per week, one hour. Each one takes one hour. And then once you pass those, we will just book one or two team feeds for you to meet one or two teams. Regarding the next one, I will send you a link to book the next interview. And also another invite for us to speak again on Wednesday, because I always do preparations. So I will just book a preparation call. It's just 15 minutes, but it's really important for you to be well prepared. So I will book a preparation call on Wednesday for us to speak again and give you the hints and tips. But in the meantime, I will send you already the scheduling link so you can book already the interview according to your availability. And also the information, like of how you should prepare the environment and so on. But that's pretty much it. So, so far, any questions, anything? No, no. All good. Okay. Perfect. So all the emails will be dropping soon. In the meantime, obviously, any questions, anything else you might have? I mean, just email me back. Okay. Okay. Perfect. So, well, in that case, thank you so much for having me here today. We will speak quite soon. Again, in the meantime, anything you might need, just let me know. Okay. Okay. Thank you so much. Perfect. You too. Thank you so much. Have a great end of day and a great week too. Have a good day. Bye. Thank you. Bye-bye.

# %% [markdown]
# ### Words and phrases

# %% [markdown]
# quick overview — краткий обзор</br>
# in a nutshell — вкратце, в двух словах</br>
# financial super app — финансовое супер-приложение</br>
# manage their finances — управлять своими финансами</br>
# scaling the application — масштабирование приложения</br>
# credit products — кредитные продукты</br>
# **absence of — отсутствие**</br>
# implementation — внедрение</br>
# buy now pay later (BNPL) — купи сейчас, плати позже</br>
# business loans — кредиты для бизнеса</br>
# fully digital **mortgage** — полностью цифровая **ипотека**</br>
# from scratch — с нуля</br>
# customize entirely — полностью адаптировать</br>
# **demands ongoing — постоянные требования / задачи**</br>
# recruitment process — процесс найма</br>
# technical rounds / stages — технические этапы собеседования</br>
# team fit — соответствие команде</br>
# give you more context — дать больше контекста</br>
