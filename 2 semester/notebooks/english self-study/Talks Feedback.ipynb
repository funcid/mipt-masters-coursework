# %% [markdown]
# ### Travel / Places

# %% [markdown]
# cable car - канатная дорога
#
# landscape - пейзаж
#
# a beautiful landscape - красивый пейзаж
#
# **fragrance** - аромат
#
# ancient - древний
#
# places of interest - достопримечательности
#
# Russian hotel - отель в России

# %% [markdown]
# ### Sports / Activities

# %% [markdown]
# sports activities - спортивные активности
#
# diving - дайвинг
#
# instructor - инструктор
#
# current of the water / flow of the water - течение воды

# %% [markdown]
# ### Useful phrases / Expressions

# %% [markdown]
# He sat behind and watched me - он сел сзади и наблюдал за мной
#
# Not in the city - не в городе
#
# I can’t share with someone - я не могу поделиться с кем-то
#
# It has changed - это изменилось
#
# It’s a game with… - это игра с…
#
# The machine **pushed itself** - машина двигалась сама
#
# I was with the master of this machine - я был с мастером этой машины
#
# Before diving, the instructor said… - перед погружением инструктор сказал…
#
# If you stop to breathe, it **could** cause problems - если перестать дышать, это может вызвать проблемы

# %% [markdown]
# ### Job Interview

# %% [markdown]
# **appropriate** - уместный, подходящий
# **suggest** - предлагать
