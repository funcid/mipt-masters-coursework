# %% [markdown]
# `affairs - дела; tires - шины; abroad - заграницей; insurance - страховая; accountant - бухгалтер`

# %% [markdown]
# ### Phrases

# %% [markdown]
# **In charge of** - ответсвенный, отвечает за

# %% [markdown]
# **Financial affairs** - финансовые дела

# %% [markdown]
# I run my own company/agency

# %% [markdown]
# `Я руковожу компанией`

# %% [markdown]
# We produce tires (cars, computers)

# %% [markdown]
# `Мы производим шины`

# %% [markdown]
# We provide high-quality car repair services

# %% [markdown]
# `Мы предоставляем высококачественные услуги ремонта машин`

# %% [markdown]
# We provide high-quality medical services abroad

# %% [markdown]
# `Мы предоставляем высококачественные медицинские услуги заграницей`

# %% [markdown]
# I run an insurance company, a low firm

# %% [markdown]
# `Я руковожу страховой компанией, юридической фирмой`

# %% [markdown]
# He's in charge of hiring people

# %% [markdown]
# `Он ответственен за найм сотрудников`
#
# *hiring* - найм; *recruting* - набор

# %% [markdown]
# Let me introduce

# %% [markdown]
# `Позвольте представить Вам`

# %% [markdown]
# ### Departments

# %% [markdown]
# Logistics, IT, Human Resources, Marketing, Sales, Finance/Accounting (бухгалтерия),

# %% [markdown]
# In what department do you work?
#
# What department are you in?

# %% [markdown]
# ### Name of jobs

# %% [markdown]
# Sales manager - менеджер по продажам

# %% [markdown]
# Meet Mary. She`s our sales manager.

# %% [markdown]
# Sales Representative (REP) - торговый представитель

# %% [markdown]
# Financial Analyst

# %% [markdown]
# An Accountant - бухгалтер
