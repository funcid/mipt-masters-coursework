# %% [markdown]
# ### Phrases

# %% [markdown]
# **Let me introduce** - позвольте мне представить

# %% [markdown]
# **In head of** - руководитель/возглавлять

# %% [markdown]
# Sales targets - планы по продажам

# %% [markdown]
# **Climbed up the career ladder** - взобраться вверх по карьерной лестнице

# %% [markdown]
# **Values him** - ценит его

# %% [markdown]
# **Considers him to be an asset** - считает его достоянием
