# %% [markdown]
# ### Phrases

# %% [markdown]
# **Sales representiative** - торговый представитель

# %% [markdown]
# **We provide insurance services** - мы предоставляем страховые сервисы

# %% [markdown]
# **Actually** - вообще-то

# %% [markdown]
# **Meeting the targets** - выполнение планов

# %% [markdown]
# **Value** - ценить/стоимость/ценность

# %% [markdown]
# The Management really values him

# %% [markdown]
# **Considers** - считают/думают/рассматривать/учитывать

# %% [markdown]
# **Are you in IT as well?** - а Вы также работаете в отделе IT?

# %% [markdown]
# **In customer service** - В отделе обслуживания клиентов

# %% [markdown]
# **Will you excuse me for a moment?** - Позволите, я отойду на минутку?

# %% [markdown]
# **It's a plesure to meet you** - приятно с вами познакомиться

# %% [markdown]
# ### A company / A business / A market

# %% [markdown]
# Local and International

# %% [markdown]
# Private or Governmental (Institution)

# %% [markdown]
# ### Present Perfect Continuous

# %% [markdown]
# Когда-то началось и все еще происходит.

# %% [markdown]
# How long have you been working here?

# %% [markdown]
# How long have you been living here?

# %% [markdown]
# How long have you been working as a Sales Representiative?
