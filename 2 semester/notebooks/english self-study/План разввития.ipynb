# %% [markdown]
# # План развития

# %% [markdown]
# Изучение технического и делового английского.

# %% [markdown]
# ### 1: Формирование базы

# %% [markdown]
# 5 недельный курс делового английского
#
# https://www.youtube.com/watch?v=Wx5DeT9C3pQ&list=PLqmO-6kSWB7YODiW77nvF934gkfyz_Oeb
#
# 1 недельный курс технического анлийского
#
# https://www.youtube.com/watch?v=4RYqlAPIfD0&list=PL0BJapvyPWKGfHnQ-aFz4abjx_vr-Ubzq

# %% [markdown]
# ### 2: Прохождение платного курса

# %% [markdown]
# Старт курса 10.02.2026
#
# Стоимость обучения 38 000 ₽
#
# Продолжительность 2 месяца
#
# https://www.hse.ru/edu/dpo/583393418
