# %% [markdown]
# # Асинхронноcть в Python

# %% [markdown]
# https://netology.ru/profile/program/bhembd-25-pdl-1/lessons/523655/lesson_items/2837334

# %% [markdown]
# ## Цель
#
# Научиться создавать простое FastAPI-приложение

# %% [markdown]
# ## Задание 1

# %% [markdown]
# Создайте FastAPI-приложение, реализующее работу простого калькулятора.
#
# Приложение должно реализовывать следующие методы:
#
# 1. Методы сложения, вычитания, умножения, деления.
# 2. Методы создания выражения, возможность добавления сложных выражений, таких как, (а+b)* c + (d - e)/(f-g). Пример: отдельный метод, который принимает аргументы a, op и b; где a, b — атрибуты. op — операция над ними.
# 3. Нужно так же реализовать возможность использования выражения в составе более сложного выражения. Пример: метод принимает строку вида (а+b)* c + (d - e)/(f-g). Бизнес-логика парсит строку, расставляет правильным образом порядок выполнения операций, производит вычисление и возвращает ответ. В этом случае потребность в выполнение пунктов 3 и 4 отпадает.
# 4. Метод просмотра текущего выражения. Метод возвращает состояние выражения сформированное на текущий момент.
# 5. Метод выполнения выражения. Метод возвращает результат выполнения выражения.

# %% [markdown]
# ### Решение

# %% [markdown]
# **Навигация**
#
# - [services](1%20%D1%81%D0%B5%D0%BC%D0%B5%D1%81%D1%82%D1%80/services)
#   - [calculator](1%20%D1%81%D0%B5%D0%BC%D0%B5%D1%81%D1%82%D1%80/services/calculator)
#     * [calculator.py](1%20%D1%81%D0%B5%D0%BC%D0%B5%D1%81%D1%82%D1%80/services/calculator/calculator.py)
#     * [main.py](1%20%D1%81%D0%B5%D0%BC%D0%B5%D1%81%D1%82%D1%80/services/calculator/main.py)
#
# **Запуск**
#
# Запускаем сервис с командой `python .\main.py`, перед этим скачав зависимости `pip install -r requirements.txt`
# ```
# PS C:\Users\func\Documents\GitHub\mipt-masters-coursework\1 семестр\services\calculator> python .\main.py
# INFO:     Started server process [59380]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:8000 (Press CTRL+C to quit)
# INFO:     127.0.0.1:61633 - "GET / HTTP/1.1" 200 OK
# ```

# %% [markdown]
# ### Проверка

# %%
# !curl -s -X POST http://127.0.0.1:8000/v1/add -H "Content-Type: application/json" -d "{\"a\":5,\"b\":3}"
# !curl -s -X POST http://127.0.0.1:8000/v1/subtract -H "Content-Type: application/json" -d "{\"a\":10,\"b\":4}"
# !curl -s -X POST http://127.0.0.1:8000/v1/multiply -H "Content-Type: application/json" -d "{\"a\":5,\"b\":3}"
# !curl -s -X POST http://127.0.0.1:8000/v1/divide -H "Content-Type: application/json" -d "{\"a\":15,\"b\":3}"
# !curl -s -X POST http://127.0.0.1:8000/v1/expression/evaluate -H "Content-Type: application/json" -d "{\"expression\":\"(2+3)*4+(10-4)/(6-3)\"}"
# !curl -s -X POST http://127.0.0.1:8000/v1/expression -H "Content-Type: application/json" -d "{\"expression\":\"2 + 3 * 4\"}"
# !curl -s -X GET http://127.0.0.1:8000/v1/expression
# !curl -s -X POST http://127.0.0.1:8000/v1/expression/execute
# Out:
# {"expression":null,"result":8.0}
# {"expression":null,"result":6.0}
# {"expression":null,"result":15.0}
# {"expression":null,"result":5.0}
# {"expression":"(2+3)*4+(10-4)/(6-3)","result":22.0}
# {"expression":"2 + 3 * 4","result":null}
# {"expression":"2 + 3 * 4","result":null}
# {"expression":"2 + 3 * 4","result":14.0}
