# %% [markdown]
# # Домашнее задание
# ## Дисциплина Основы Python
# ### Тема Тема 1. Основы Python
#
# Цель задания Овладеть базовым навыками работы с кодом и переменными
# Инструменты для выполнения ДЗ Jupyter Notebook или Google Colab
# Правила приёма работы Прикрепите ссылку на выполненное задание в Google Colab или GitHub (если вы использовали Jupyter Notebook).

# %% [markdown]
# ### Задание 1
# Напишите код на Python в среде Jupyter Notebook для решения следующей задачи.
#
# Дана переменная, в которой хранится четырёхзначное число (год). Необходимо написать программу, которая выведет, является этот год високосным или обычным.
# Пример работы программы:
#
# ```
# year = 2020
# Результат:
# Високосный год
# ```
#
# ```
# year = 2019
# Результат:
# Обычный год
# ```

# %%
year = 2020

print("Результат:")

if year % 4 == 0:
    print("Високосный год")
else:
    print("Обычный год")
# Out:
# Результат:
# Високосный год

# %% [markdown]
# ### Задание 2 (необязательное)
# Написать код на Python в среде Jupyter Notebook для решения следующей задачи.
#
# Дана переменная, в которой хранится шестизначное число (номер проездного билета). Напишите программу, которая будет определять, является ли этот билет счастливым. Билет считается счастливым, если сумма первых трёх цифр совпадает с суммой последних трёх цифр номера.
# Примеры работы программы:
#
# ```
# number = 123456
# Результат:
# Несчастливый билет
# ```
#
# ```
# number = 123321
# Результат:
# Счастливый билет
# ```

# %%
number = 123321
string = str(number)

print("Результат:")

if string[0] + string[1] + string[2] == string[3] + string[4] + string[5]:
    print("Счастливый билет")
else:
    print("Несчастливый билет")
# Out:
# Результат:
# Несчастливый билет
